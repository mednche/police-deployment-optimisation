# %% [markdown]
# # ABM SA (sensitivity analysis)

# %% [markdown]
# This notebook containts the following tests for the ABM sensitivity analyses:
# 1. Number of streets to patrol (SA_hotStreets.py). Range: 2, 5, 10. For 4 agents per precinct (targetted deployement to hottest beats) and the SA_set of 100 shifts randomly chosen throughout 2018.

# %%
import os
print(os.getcwd())

import osmnx as ox
import pandas as pd

from datetime import datetime, timedelta, time
import datetime
import numpy as np
import scipy as sp

import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import seaborn as sns
import matplotlib as mpl
import pickle

import random

import warnings
# Out:
# /Users/natachachenevoy/Documents/GitHub/ABM-Detroit-Police-Dispatch/Validation

# %% [markdown]
# ## 1 - Select 100 random (from 2018) shifts for SA_set

# %%
data = pd.read_csv("../data/incidents.csv")
data.Date_Time = pd.to_datetime(data.Date_Time)
data.Date_Time = data.Date_Time.dt.tz_localize(None)
#cfs_incidents['Patrol_beat'] = cfs_incidents['Patrol_beat'].apply(str)
#cfs_incidents['Precinct'] = cfs_incidents['Precinct'].apply(str)

# SELECT 2018 for validation (so that 2017 can be used for historical crimes)
data = data[(data['Date_Time'].dt.year == 2018)]

# %%
dates_uniques = data['Date_Time'].sort_values().dt.date.unique()
# Remove first and last date for full days.
#dates_uniques_weekdays = dates_uniques_weekdays[1:-2]
print('There are {} unique dates in dataset'.format(len(dates_uniques)))
# Out:
# There are 365 unique dates in dataset

# %%
# DF of shifts start and end times (plus duration)
shifts = pd.DataFrame({'start':[0, 8, 16], 'end':[8,16,24], 
                      'duration': [8,8,8]})
shifts
# Out:
#    start  end  duration
# 0      0    8         8
# 1      8   16         8
# 2     16   24         8

# %%
def get_3_shifts_for_date(date, df_shifts) :

    # Add new column with start date
    df_shifts = df_shifts.assign(date_start = np.repeat(date, 3))

    return df_shifts


list_of_dfs = [get_3_shifts_for_date(date, shifts) for date in dates_uniques]  
df_shifts = pd.concat(list_of_dfs, ignore_index=True)
df_shifts
# Out:
#       start  end  duration  date_start
# 0         0    8         8  2018-01-01
# 1         8   16         8  2018-01-01
# 2        16   24         8  2018-01-01
# 3         0    8         8  2018-01-02
# 4         8   16         8  2018-01-02
# ...     ...  ...       ...         ...
# 1090      8   16         8  2018-12-30
# 1091     16   24         8  2018-12-30
# 1092      0    8         8  2018-12-31
# 1093      8   16         8  2018-12-31
# 1094     16   24         8  2018-12-31
#
# [1095 rows x 4 columns]

# %%
def get_start_end_shift(row):
    start_date = row['date_start']
    start_time = datetime.time(row['start'],0)
    
    duration_hours = int(row['duration'])


    SHIFT_START_DT = datetime.datetime.combine(start_date, start_time)
    SHIFT_END_DT = SHIFT_START_DT + timedelta(hours = duration_hours)
    END_TIME = SHIFT_END_DT.time()

    #print('Shift is from {} to {}'.format(SHIFT_START_DT,SHIFT_END_DT))
    #print('duration: {} hours'.format(SHIFT_END_DT - SHIFT_START_DT))
    return SHIFT_START_DT, SHIFT_END_DT



list_all_shifts = df_shifts.apply(get_start_end_shift, axis = 1)
list_all_shifts[0:5]
# Out:
# 0    (2018-01-01 00:00:00, 2018-01-01 08:00:00)
# 1    (2018-01-01 08:00:00, 2018-01-01 16:00:00)
# 2    (2018-01-01 16:00:00, 2018-01-02 00:00:00)
# 3    (2018-01-02 00:00:00, 2018-01-02 08:00:00)
# 4    (2018-01-02 08:00:00, 2018-01-02 16:00:00)
# dtype: object

# %%
np.random.seed(22)
# Sample without replacement
SA_set = np.random.choice(pd.Series([pair for pair in list_all_shifts if pair[0].year == 2018]), 100, replace = False)

print('SA_set:', len(set(SA_set)))
# Out:
# SA_set: 100

# %% [markdown]
# ## SAVE FILES

# %%
import pickle
with open('./SA_set.pkl', 'wb') as f:
    pickle.dump(SA_set, f)

# %%
with open('SA_set.pkl', 'rb') as f:
    shifts = pickle.load(f)
shifts
# Out:
# array([(datetime.datetime(2018, 2, 27, 0, 0), datetime.datetime(2018, 2, 27, 8, 0)),
#        (datetime.datetime(2018, 2, 3, 8, 0), datetime.datetime(2018, 2, 3, 16, 0)),
#        (datetime.datetime(2018, 4, 14, 8, 0), datetime.datetime(2018, 4, 14, 16, 0)),
#        (datetime.datetime(2018, 8, 30, 16, 0), datetime.datetime(2018, 8, 31, 0, 0)),
#        (datetime.datetime(2018, 1, 28, 8, 0), datetime.datetime(2018, 1, 28, 16, 0)),
#        (datetime.datetime(2018, 7, 30, 16, 0), datetime.datetime(2018, 7, 31, 0, 0)),
#        (datetime.datetime(2018, 6, 30, 0, 0), datetime.datetime(2018, 6, 30, 8, 0)),
#        (datetime.datetime(2018, 3, 31, 16, 0), datetime.datetime(2018, 4, 1, 0, 0)),
#        (datetime.datetime(2018, 9, 17, 8, 0), datetime.datetime(2018, 9, 17, 16, 0)),
#        (datetime.datetime(2018, 12, 28, 0, 0), datetime.datetime(2018, 12, 28, 8, 0)),
#        (datetime.datetime(2018, 1, 2, 16, 0), datetime.datetime(2018, 1, 3, 0, 0)),
#        (datetime.datetime(2018, 11, 6, 0, 0), datetime.datetime(2018, 11, 6, 8, 0)),
#        (datetime.datetime(2018, 11, 28, 8, 0), datetime.datetime(2018, 11, 28, 16, 0)),
#        (datetime.datetime(2018, 4, 21, 8, 0), datetime.datetime(2018, 4, 21, 16, 0)),
#        (datetime.datetime(2018, 4, 13, 16, 0), datetime.datetime(2018, 4, 14, 0, 0)),
#        (datetime.datetime(2018, 12, 25, 16, 0), datetime.datetime(2018, 12, 26, 0, 0)),
#        (datetime.datetime(2018, 9, 18, 8, 0), datetime.datetime(2018, 9, 18, 16, 0)),
#        (datetime.datetime(2018, 4, 11, 16, 0), datetime.datetime(2018, 4, 12, 0, 0)),
#        (datetime.datetime(2018, 11, 21, 0, 0), datetime.datetime(2018, 11, 21, 8, 0)),
#        (datetime.datetime(2018, 5, 25, 0, 0), datetime.datetime(2018, 5, 25, 8, 0)),
#        (datetime.datetime(2018, 10, 11, 8, 0), datetime.datetime(2018, 10, 11, 16, 0)),
#        (datetime.datetime(2018, 5, 26, 8, 0), datetime.datetime(2018, 5, 26, 16, 0)),
#        (datetime.datetime(2018, 5, 11, 8, 0), datetime.datetime(2018, 5, 11, 16, 0)),
#        (datetime.datetime(2018, 2, 13, 8, 0), datetime.datetime(2018, 2, 13, 16, 0)),
#        (datetime.datetime(2018, 7, 10, 0, 0), datetime.datetime(2018, 7, 10, 8, 0)),
#        (datetime.datetime(2018, 11, 11, 16, 0), datetime.datetime(2018, 11, 12, 0, 0)),
#        (datetime.datetime(2018, 3, 13, 0, 0), datetime.datetime(2018, 3, 13, 8, 0)),
#        (datetime.datetime(2018, 5, 1, 8, 0), datetime.datetime(2018, 5, 1, 16, 0)),
#        (datetime.datetime(2018, 10, 31, 8, 0), datetime.datetime(2018, 10, 31, 16, 0)),
#        (datetime.datetime(2018, 9, 2, 8, 0), datetime.datetime(2018, 9, 2, 16, 0)),
#        (datetime.datetime(2018, 7, 15, 8, 0), datetime.datetime(2018, 7, 15, 16, 0)),
#        (datetime.datetime(2018, 7, 7, 8, 0), datetime.datetime(2018, 7, 7, 16, 0)),
#        (datetime.datetime(2018, 2, 9, 0, 0), datetime.datetime(2018, 2, 9, 8, 0)),
#        (datetime.datetime(2018, 10, 25, 8, 0), datetime.datetime(2018, 10, 25, 16, 0)),
#        (datetime.datetime(2018, 4, 24, 16, 0), datetime.datetime(2018, 4, 25, 0, 0)),
#        (datetime.datetime(2018, 2, 21, 16, 0), datetime.datetime(2018, 2, 22, 0, 0)),
#        (datetime.datetime(2018, 5, 5, 0, 0), datetime.datetime(2018, 5, 5, 8, 0)),
#        (datetime.datetime(2018, 11, 1, 0, 0), datetime.datetime(2018, 11, 1, 8, 0)),
#        (datetime.datetime(2018, 2, 18, 8, 0), datetime.datetime(2018, 2, 18, 16, 0)),
#        (datetime.datetime(2018, 10, 9, 0, 0), datetime.datetime(2018, 10, 9, 8, 0)),
#        (datetime.datetime(2018, 4, 8, 16, 0), datetime.datetime(2018, 4, 9, 0, 0)),
#        (datetime.datetime(2018, 9, 3, 16, 0), datetime.datetime(2018, 9, 4, 0, 0)),
#        (datetime.datetime(2018, 10, 5, 16, 0), datetime.datetime(2018, 10, 6, 0, 0)),
#        (datetime.datetime(2018, 4, 6, 16, 0), datetime.datetime(2018, 4, 7, 0, 0)),
#        (datetime.datetime(2018, 4, 1, 16, 0), datetime.datetime(2018, 4, 2, 0, 0)),
#        (datetime.datetime(2018, 2, 11, 16, 0), datetime.datetime(2018, 2, 12, 0, 0)),
#        (datetime.datetime(2018, 5, 15, 0, 0), datetime.datetime(2018, 5, 15, 8, 0)),
#        (datetime.datetime(2018, 11, 15, 16, 0), datetime.datetime(2018, 11, 16, 0, 0)),
#        (datetime.datetime(2018, 6, 9, 0, 0), datetime.datetime(2018, 6, 9, 8, 0)),
#        (datetime.datetime(2018, 3, 22, 16, 0), datetime.datetime(2018, 3, 23, 0, 0)),
#        (datetime.datetime(2018, 8, 17, 0, 0), datetime.datetime(2018, 8, 17, 8, 0)),
#        (datetime.datetime(2018, 4, 17, 16, 0), datetime.datetime(2018, 4, 18, 0, 0)),
#        (datetime.datetime(2018, 1, 20, 0, 0), datetime.datetime(2018, 1, 20, 8, 0)),
#        (datetime.datetime(2018, 9, 29, 16, 0), datetime.datetime(2018, 9, 30, 0, 0)),
#        (datetime.datetime(2018, 5, 2, 0, 0), datetime.datetime(2018, 5, 2, 8, 0)),
#        (datetime.datetime(2018, 7, 20, 16, 0), datetime.datetime(2018, 7, 21, 0, 0)),
#        (datetime.datetime(2018, 11, 19, 16, 0), datetime.datetime(2018, 11, 20, 0, 0)),
#        (datetime.datetime(2018, 12, 11, 8, 0), datetime.datetime(2018, 12, 11, 16, 0)),
#        (datetime.datetime(2018, 2, 2, 8, 0), datetime.datetime(2018, 2, 2, 16, 0)),
#        (datetime.datetime(2018, 5, 23, 16, 0), datetime.datetime(2018, 5, 24, 0, 0)),
#        (datetime.datetime(2018, 8, 24, 0, 0), datetime.datetime(2018, 8, 24, 8, 0)),
#        (datetime.datetime(2018, 2, 14, 16, 0), datetime.datetime(2018, 2, 15, 0, 0)),
#        (datetime.datetime(2018, 1, 16, 8, 0), datetime.datetime(2018, 1, 16, 16, 0)),
#        (datetime.datetime(2018, 10, 10, 16, 0), datetime.datetime(2018, 10, 11, 0, 0)),
#        (datetime.datetime(2018, 3, 29, 0, 0), datetime.datetime(2018, 3, 29, 8, 0)),
#        (datetime.datetime(2018, 4, 23, 8, 0), datetime.datetime(2018, 4, 23, 16, 0)),
#        (datetime.datetime(2018, 12, 8, 0, 0), datetime.datetime(2018, 12, 8, 8, 0)),
#        (datetime.datetime(2018, 7, 7, 16, 0), datetime.datetime(2018, 7, 8, 0, 0)),
#        (datetime.datetime(2018, 10, 2, 8, 0), datetime.datetime(2018, 10, 2, 16, 0)),
#        (datetime.datetime(2018, 3, 25, 8, 0), datetime.datetime(2018, 3, 25, 16, 0)),
#        (datetime.datetime(2018, 6, 23, 0, 0), datetime.datetime(2018, 6, 23, 8, 0)),
#        (datetime.datetime(2018, 8, 31, 16, 0), datetime.datetime(2018, 9, 1, 0, 0)),
#        (datetime.datetime(2018, 6, 2, 16, 0), datetime.datetime(2018, 6, 3, 0, 0)),
#        (datetime.datetime(2018, 2, 25, 16, 0), datetime.datetime(2018, 2, 26, 0, 0)),
#        (datetime.datetime(2018, 12, 31, 0, 0), datetime.datetime(2018, 12, 31, 8, 0)),
#        (datetime.datetime(2018, 2, 19, 8, 0), datetime.datetime(2018, 2, 19, 16, 0)),
#        (datetime.datetime(2018, 7, 1, 0, 0), datetime.datetime(2018, 7, 1, 8, 0)),
#        (datetime.datetime(2018, 1, 2, 0, 0), datetime.datetime(2018, 1, 2, 8, 0)),
#        (datetime.datetime(2018, 9, 27, 8, 0), datetime.datetime(2018, 9, 27, 16, 0)),
#        (datetime.datetime(2018, 10, 16, 16, 0), datetime.datetime(2018, 10, 17, 0, 0)),
#        (datetime.datetime(2018, 11, 26, 8, 0), datetime.datetime(2018, 11, 26, 16, 0)),
#        (datetime.datetime(2018, 1, 23, 8, 0), datetime.datetime(2018, 1, 23, 16, 0)),
#        (datetime.datetime(2018, 2, 15, 8, 0), datetime.datetime(2018, 2, 15, 16, 0)),
#        (datetime.datetime(2018, 4, 6, 0, 0), datetime.datetime(2018, 4, 6, 8, 0)),
#        (datetime.datetime(2018, 3, 18, 16, 0), datetime.datetime(2018, 3, 19, 0, 0)),
#        (datetime.datetime(2018, 12, 15, 8, 0), datetime.datetime(2018, 12, 15, 16, 0)),
#        (datetime.datetime(2018, 10, 1, 0, 0), datetime.datetime(2018, 10, 1, 8, 0)),
#        (datetime.datetime(2018, 2, 10, 16, 0), datetime.datetime(2018, 2, 11, 0, 0)),
#        (datetime.datetime(2018, 5, 19, 0, 0), datetime.datetime(2018, 5, 19, 8, 0)),
#        (datetime.datetime(2018, 6, 8, 16, 0), datetime.datetime(2018, 6, 9, 0, 0)),
#        (datetime.datetime(2018, 7, 31, 8, 0), datetime.datetime(2018, 7, 31, 16, 0)),
#        (datetime.datetime(2018, 8, 28, 0, 0), datetime.datetime(2018, 8, 28, 8, 0)),
#        (datetime.datetime(2018, 10, 16, 8, 0), datetime.datetime(2018, 10, 16, 16, 0)),
#        (datetime.datetime(2018, 3, 3, 0, 0), datetime.datetime(2018, 3, 3, 8, 0)),
#        (datetime.datetime(2018, 10, 23, 8, 0), datetime.datetime(2018, 10, 23, 16, 0)),
#        (datetime.datetime(2018, 8, 20, 8, 0), datetime.datetime(2018, 8, 20, 16, 0)),
#        (datetime.datetime(2018, 2, 12, 16, 0), datetime.datetime(2018, 2, 13, 0, 0)),
#        (datetime.datetime(2018, 6, 3, 16, 0), datetime.datetime(2018, 6, 4, 0, 0)),
#        (datetime.datetime(2018, 10, 24, 8, 0), datetime.datetime(2018, 10, 24, 16, 0)),
#        (datetime.datetime(2018, 2, 1, 8, 0), datetime.datetime(2018, 2, 1, 16, 0))],
#       dtype=object)

# %% [markdown]
# ## 2 - Run SA on HPC

# %% [markdown]
# ## 3 - Interprete results here

# %% [markdown]
# ### 1. Number of hot streets

# %%
with open('dict_SA_hotStreets.pkl', 'rb') as f:
        dict_num_hot_streets = pickle.load(f)
dict_num_hot_streets
# Out:
# {2: [3296,
#   3222,
#   3162,
#   1499,
#   4080,
#   1205,
#   4192,
#   922,
#   2725,
#   4637,
#   2500,
#   2553,
#   3084,
#   3811,
#   1351,
#   860,
#   3245,
#   1907,
#   2955,
#   6841,
#   7731,
#   4814,
#   7266,
#   3754,
#   3668,
#   1302,
#   3330,
#   3750,
#   3176,
#   3986,
#   3924,
#   4079,
#   5876,
#   7068,
#   1808,
#   2049,
#   3659,
#   7716,
#   4125,
#   3204,
#   788,
#   1182,
#   1204,
#   1479,
#   867,
#   714,
#   3543,
#   1325,
#   4891,
#   1544,
#   6644,
#   1866,
#   3281,
#   913,
#   3572,
#   1307,
#   1205,
#   3424,
#   5851,
#   1955,
#   6989,
#   1978,
#   4055,
#   1299,
#   7933,
#   3182,
#   4004,
#   1019,
#   3120,
#   4466,
#   5001,
#   1237,
#   998,
#   910,
#   2755,
#   3676,
#   3910,
#   3708,
#   7691,
#   1002,
#   3279,
#   3747,
#   7482,
#   5787,
#   902,
#   4026,
#   2586,
#   1012,
#   4796,
#   1327,
#   3694,
#   3253,
#   3070,
#   3109,
#   2764,
#   3025,
#   1561,
#   1184,
#   3298,
#   7682],
#  5: [3527,
#   3134,
#   2913,
#   1434,
#   3838,
#   1180,
#   3803,
#   939,
#   2626,
#   5165,
#   2572,
#   2930,
#   3283,
#   3830,
#   1328,
#   989,
#   2977,
#   2192,
#   2988,
#   7243,
#   6880,
#   5054,
#   7585,
#   3666,
#   3547,
#   1305,
#   3282,
#   3852,
#   3301,
#   4113,
#   4006,
#   4099,
#   5609,
#   7470,
#   1974,
#   2009,
#   3789,
#   7095,
#   4352,
#   2956,
#   939,
#   1303,
#   1269,
#   1267,
#   881,
#   831,
#   3988,
#   1337,
#   4652,
#   1674,
#   6725,
#   2245,
#   3561,
#   894,
#   3766,
#   1339,
#   1184,
#   3574,
#   5446,
#   2252,
#   7834,
#   2267,
#   3482,
#   1421,
#   8528,
#   3395,
#   4261,
#   938,
#   2967,
#   4194,
#   4892,
#   1282,
#   1205,
#   974,
#   2977,
#   3474,
#   3919,
#   3747,
#   8090,
#   949,
#   3492,
#   3642,
#   7768,
#   6127,
#   961,
#   4280,
#   2622,
#   1011,
#   5102,
#   1298,
#   3512,
#   2891,
#   2925,
#   2979,
#   3078,
#   3150,
#   1499,
#   1048,
#   3243,
#   7940],
#  10: [3791,
#   3680,
#   3329,
#   1419,
#   4179,
#   1426,
#   4397,
#   1013,
#   2696,
#   5488,
#   2573,
#   2840,
#   3352,
#   3706,
#   1308,
#   972,
#   3335,
#   2080,
#   3159,
#   7447,
#   7564,
#   5035,
#   7220,
#   3547,
#   3683,
#   1405,
#   3496,
#   4022,
#   3548,
#   4571,
#   3904,
#   4214,
#   5150,
#   7255,
#   1906,
#   2250,
#   3618,
#   7284,
#   4418,
#   2992,
#   843,
#   1339,
#   1276,
#   1421,
#   903,
#   780,
#   3942,
#   1363,
#   4952,
#   1608,
#   6865,
#   2053,
#   3589,
#   978,
#   3775,
#   1368,
#   1350,
#   3530,
#   5777,
#   2413,
#   6584,
#   2115,
#   3661,
#   1614,
#   7956,
#   3602,
#   4357,
#   994,
#   3002,
#   4505,
#   4510,
#   1303,
#   1239,
#   972,
#   3093,
#   3862,
#   3934,
#   4081,
#   8457,
#   1124,
#   3416,
#   3381,
#   8088,
#   6272,
#   829,
#   4044,
#   2733,
#   1069,
#   4955,
#   1468,
#   3730,
#   3333,
#   2684,
#   3485,
#   3046,
#   3306,
#   1626,
#   1135,
#   3477,
#   8122]}

# %%
df = pd.DataFrame.from_dict(dict_num_hot_streets)
df
# Out:
#       2     5     10
# 0   3296  3527  3791
# 1   3222  3134  3680
# 2   3162  2913  3329
# 3   1499  1434  1419
# 4   4080  3838  4179
# ..   ...   ...   ...
# 95  3025  3150  3306
# 96  1561  1499  1626
# 97  1184  1048  1135
# 98  3298  3243  3477
# 99  7682  7940  8122
#
# [100 rows x 3 columns]

# %%
f, ax = plt.subplots(1, figsize=(15, 5))
sns.boxplot( data=df, ax = ax)


#f.suptitle('Total crime deterrence score for 2, 5 and 10 streets to patrol per beat', fontsize=20)


ax.set_xticklabels(ax.get_xticklabels(),rotation=0,  fontsize=15)


ax.set(xlabel=None)

ax.set_ylabel('Total crime deterrence score', fontsize = 16)

ax.tick_params(axis='y', labelsize=15)

#ax.set_title('Total crime deterrence score for 2, 5 and 10 streets to patrol per beat', fontsize = 16)

#ax1.set_ylim(0,50)

plt.savefig('../Images/SA_hotStreets.png', bbox_inches = 'tight')




plt.show()

# %%
num_agents = 4

# %%
"""filter_col = ['Real_dispatch_time', "Dispatch_time_{}".format(num_agents)]
df3 = df2[filter_col]
df3.columns = ['Observed', 'Generated']
df3.Generated.describe()"""
# Out:
# 'filter_col = [\'Real_dispatch_time\', "Dispatch_time_{}".format(num_agents)]\ndf3 = df2[filter_col]\ndf3.columns = [\'Observed\', \'Generated\']\ndf3.Generated.describe()'

# %% [markdown]
# ## Time saving (for dispatcher's redispatching on the fly)

# %%
with open('dict_pair_SA_timeSaving.pkl', 'rb') as f:
        dict_time_saving_percent= pickle.load(f)
#dict_time_saving_percent

# %%
dict_time_saving_percent[30]
# Out:
#       Index Precinct Patrol_beat           Date_Time  Real_dispatch_time  \
# 0     51870        2         201 2018-02-27 00:09:24                 1.9
# 1     51871       11        1103 2018-02-27 00:19:13                 2.1
# 2     51872       11        1102 2018-02-27 00:24:03                 1.5
# 3     51873        7         708 2018-02-27 00:37:00                 1.7
# 4     51874        2         204 2018-02-27 00:40:16                 1.7
# ...     ...      ...         ...                 ...                 ...
# 4785  49167        6         612 2018-02-01 15:25:57                 6.8
# 4786  49168        4         402 2018-02-01 15:28:33                 8.9
# 4787  49169        8         810 2018-02-01 15:34:49                 0.5
# 4788  49170        9         911 2018-02-01 15:43:39                 1.1
# 4789  49171        7         711 2018-02-01 15:54:25                 1.8
#
#       Real_travel_time  Dispatch_time  Travel_time
# 0                  8.0              1          1.0
# 1                  2.6              1          4.0
# 2                  5.1              1          3.0
# 3                  3.1              1          3.0
# 4                  0.2              1          2.0
# ...                ...            ...          ...
# 4785               5.0              1          4.0
# 4786              14.6              1          2.0
# 4787               4.5              1          2.0
# 4788               8.0              1          4.0
# 4789               2.2              1          1.0
#
# [4790 rows x 8 columns]

# %%
# Initialise the dataframe 
df2 = pd.DataFrame()
list_time_saving_percent = [10,20,30] 

for time_saving_percent in list_time_saving_percent:

    if len(df2) == 0:
        df2 = dict_time_saving_percent[time_saving_percent].copy()

    incidents = dict_time_saving_percent[time_saving_percent]
    # get the new incidents if any
    common = incidents.merge(df2,on=['Index'])
    new_incidents = incidents[(~incidents.Index.isin(common.Index))]
    # add new incidents to df2
    df2 = pd.concat([df2, new_incidents])

    df2['Dispatch_time_{}'.format(time_saving_percent)] = dict_time_saving_percent[time_saving_percent]['Dispatch_time']
    df2['Travel_time_{}'.format(time_saving_percent)] = dict_time_saving_percent[time_saving_percent]['Travel_time']

df2
# Out:
#       Index Precinct Patrol_beat           Date_Time  Real_dispatch_time  \
# 0     51870        2         201 2018-02-27 00:09:24                 1.9
# 1     51871       11        1103 2018-02-27 00:19:13                 2.1
# 2     51872       11        1102 2018-02-27 00:24:03                 1.5
# 3     51873        7         708 2018-02-27 00:37:00                 1.7
# 4     51874        2         204 2018-02-27 00:40:16                 1.7
# ...     ...      ...         ...                 ...                 ...
# 4785  49167        6         612 2018-02-01 15:25:57                 6.8
# 4786  49168        4         402 2018-02-01 15:28:33                 8.9
# 4787  49169        8         810 2018-02-01 15:34:49                 0.5
# 4788  49170        9         911 2018-02-01 15:43:39                 1.1
# 4789  49171        7         711 2018-02-01 15:54:25                 1.8
#
#       Real_travel_time  Dispatch_time  Travel_time  Dispatch_time_10  \
# 0                  8.0              1          1.0               1.0
# 1                  2.6              1          4.0               1.0
# 2                  5.1              1          3.0               1.0
# 3                  3.1              1          3.0               1.0
# 4                  0.2              1          2.0               1.0
# ...                ...            ...          ...               ...
# 4785               5.0              1          4.0               1.0
# 4786              14.6              1          2.0               1.0
# 4787               4.5              1          2.0               1.0
# 4788               8.0              1          4.0               1.0
# 4789               2.2              1          1.0               1.0
#
#       Travel_time_10  Dispatch_time_20  Travel_time_20  Dispatch_time_30  \
# 0                1.0               1.0             1.0                 1
# 1                4.0               1.0             4.0                 1
# 2                3.0               1.0             3.0                 1
# 3                3.0               1.0             3.0                 1
# 4                2.0               1.0             2.0                 1
# ...              ...               ...             ...               ...
# 4785             4.0               1.0             4.0                 1
# 4786             2.0               1.0             2.0                 1
# 4787             2.0               1.0             2.0                 1
# 4788             4.0               1.0             4.0                 1
# 4789             1.0               1.0             1.0                 1
#
#       Travel_time_30
# 0                1.0
# 1                4.0
# 2                3.0
# 3                3.0
# 4                2.0
# ...              ...
# 4785             4.0
# 4786             2.0
# 4787             2.0
# 4788             4.0
# 4789             1.0
#
# [4790 rows x 14 columns]

# %%
filter_col = ["Travel_time_10", 'Travel_time_20', 'Travel_time_30', 'Travel_time_40', 'Travel_time_50', 'Travel_time_60']
df3 = df2[filter_col]
df3.columns = ['10%', '20%', '30%', '40%', '50%', '60%']
df3
# Out:
#       10%  20%  30%
# 0     1.0  1.0  1.0
# 1     4.0  4.0  4.0
# 2     3.0  3.0  3.0
# 3     3.0  3.0  3.0
# 4     2.0  2.0  2.0
# ...   ...  ...  ...
# 4785  4.0  4.0  4.0
# 4786  2.0  2.0  2.0
# 4787  2.0  2.0  2.0
# 4788  4.0  4.0  4.0
# 4789  1.0  1.0  1.0
#
# [4790 rows x 3 columns]

# %%
# plot the boxplot 
f, ax = plt.subplots(1, figsize=(15, 5))

## DISPATCH

ax = sns.boxplot(data=df3, ax = ax)


#f.suptitle('Distribution of incident travel times with various values of time saving threshold for redispatching on the fly', fontsize=20)


ax.set_xticklabels(ax.get_xticklabels(),rotation=0,  fontsize=15)
ax.tick_params(axis='y', labelsize=15)

ax.set(xlabel=None)


ax.set_ylabel('Incident travel time (mins)', fontsize = 16)





#plt.savefig('../Images/SA_timeSaving.png', bbox_inches = 'tight')


plt.show()

# %%
df2.Travel_time_10.describe()
# Out:
# count    4789.000000
# mean        2.903947
# std         1.527923
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: Travel_time_10, dtype: float64

# %%
df2.Travel_time_20.describe()
# Out:
# count    4789.000000
# mean        2.904155
# std         1.528414
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: Travel_time_20, dtype: float64

# %%
df2.Travel_time_30.describe()
# Out:
# count    4789.000000
# mean        2.905617
# std         1.529120
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: Travel_time_30, dtype: float64

# %% [markdown]
# ## Travel speed (agents)

# %%
with open('dict_SA_travelSpeed.pkl', 'rb') as f:
    dict_travel_speed_percent= pickle.load(f)
#dict_time_saving_percent
dict_travel_speed_percent

# %%
# Initialise the dataframe 
df2 = pd.DataFrame()
list_travel_speed_percent = [10,20,-10,-20]

for travel_speed_percent in list_travel_speed_percent:

    if len(df2) == 0:
        df2 = dict_travel_speed_percent[travel_speed_percent].copy()

    incidents = dict_travel_speed_percent[travel_speed_percent]
    # get the new incidents if any
    common = incidents.merge(df2,on=['Index'])
    new_incidents = incidents[(~incidents.Index.isin(common.Index))]
    # add new incidents to df2
    df2 = pd.concat([df2, new_incidents])

    df2['Dispatch_time_{}'.format(time_saving_percent)] = dict_travel_speed_percent[travel_speed_percent]['Dispatch_time']
    df2['Travel_time_{}'.format(time_saving_percent)] = dict_travel_speed_percent[travel_speed_percent]['Travel_time']

df2

# %%
filter_col = ["Travel_time_10", 'Travel_time_20', 'Travel_time_-10', 'Travel_time_-20']
df3 = df2[filter_col]
df3.columns = ['+10%', '+20%', '-10%', '-20%',]
df3

# %%
# plot the boxplot 
f, ax = plt.subplots(1, figsize=(15, 5))

## DISPATCH

ax = sns.boxplot(data=df3, ax = ax)


#f.suptitle('Distribution of incident travel times with various values of time saving threshold for redispatching on the fly', fontsize=20)


ax.set_xticklabels(ax.get_xticklabels(),rotation=0,  fontsize=15)
ax.tick_params(axis='y', labelsize=15)

ax.set(xlabel=None)


ax.set_ylabel('Incident travel time (mins)', fontsize = 16)





#plt.savefig('../Images/SA_travelSpeed.png', bbox_inches = 'tight')


plt.show()
